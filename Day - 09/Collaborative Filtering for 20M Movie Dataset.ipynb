# %% [markdown]
# ### This is the biggest version of 100k ratings one containing `20M ratings`. It is also taken from the movielens platform. You can find it under older versions section
#
# You can download the dataset from [here](https://grouplens.org/datasets/movielens/?utm_source=chatgpt.com)

# %%
df = spark.read.table("dai.phase2.movie_ratings")
display(df.head(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>userId</th><th>movieId</th><th>rating</th><th>timestamp</th></tr></thead><tbody><tr><td>122289</td><td>3213</td><td>4.0</td><td>1286658715</td></tr><tr><td>122289</td><td>3235</td><td>3.0</td><td>1287251632</td></tr><tr><td>122289</td><td>3253</td><td>4.0</td><td>1286592571</td></tr><tr><td>122289</td><td>3254</td><td>4.0</td><td>1286648580</td></tr><tr><td>122289</td><td>3275</td><td>3.5</td><td>1286589772</td></tr><tr><td>122289</td><td>3364</td><td>3.5</td><td>1328060352</td></tr><tr><td>122289</td><td>3384</td><td>3.5</td><td>1327271097</td></tr><tr><td>122289</td><td>3388</td><td>1.0</td><td>1286651676</td></tr><tr><td>122289</td><td>3409</td><td>1.5</td><td>1286649072</td></tr><tr><td>122289</td><td>3421</td><td>4.5</td><td>1286589750</td></tr></tbody></table></div>

# %%
df.printSchema()
print(f"Shape: ({df.count()},{len(df.columns)})")
# Out:
# root
#  |-- userId: integer (nullable = true)
#  |-- movieId: integer (nullable = true)
#  |-- rating: double (nullable = true)
#  |-- timestamp: integer (nullable = true)
#
# Shape: (20000263,4)

# %%
ratings = df.drop("timestamp")
display(ratings.head(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>userId</th><th>movieId</th><th>rating</th></tr></thead><tbody><tr><td>122289</td><td>3213</td><td>4.0</td></tr><tr><td>122289</td><td>3235</td><td>3.0</td></tr><tr><td>122289</td><td>3253</td><td>4.0</td></tr><tr><td>122289</td><td>3254</td><td>4.0</td></tr><tr><td>122289</td><td>3275</td><td>3.5</td></tr><tr><td>122289</td><td>3364</td><td>3.5</td></tr><tr><td>122289</td><td>3384</td><td>3.5</td></tr><tr><td>122289</td><td>3388</td><td>1.0</td></tr><tr><td>122289</td><td>3409</td><td>1.5</td></tr><tr><td>122289</td><td>3421</td><td>4.5</td></tr></tbody></table></div>

# %%
display(ratings.select("rating").distinct())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>rating</th></tr></thead><tbody><tr><td>0.5</td></tr><tr><td>1.5</td></tr><tr><td>5.0</td></tr><tr><td>2.0</td></tr><tr><td>4.0</td></tr><tr><td>2.5</td></tr><tr><td>3.0</td></tr><tr><td>4.5</td></tr><tr><td>3.5</td></tr><tr><td>1.0</td></tr></tbody></table></div>

# %% [markdown]
# ### Training the ALS(Alternating Least Square) Model:
#
# > #### Steps to train ALS Model:
# > 1. Split the data and train and test sets
# > 2. Create ALS Model
# > 3. Train the Model
# > 4. Make Predictions
# > 5. Evaluate
#
# ---

# %%
# Creating the train and test data set
train, test = ratings.randomSplit([0.7, 0.3], seed=42)

# %%
train.count(),test.count()
# Out:
# (13999161, 6001102)

# %%
from pyspark.ml.recommendation import ALS

als = ALS(
    userCol="userId",
    itemCol="movieId",
    ratingCol="rating",
    rank=43,              # number of latent factors
    maxIter=10,           # number of iterations
    regParam=0.02,         # regularization
    implicitPrefs=False,  # because these are real ratings
    coldStartStrategy="drop"  # If a user appears in test not in train, this will drop those types of rows to prevent predicitng NaN
)

# %%
# Training the model
model = als.fit(train)

# %%
predictions = model.transform(test)
display(predictions.head(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>userId</th><th>movieId</th><th>rating</th><th>prediction</th></tr></thead><tbody><tr><td>1021</td><td>904</td><td>5.0</td><td>4.4019598960876465</td></tr><tr><td>1021</td><td>908</td><td>5.0</td><td>4.5041399002075195</td></tr><tr><td>1021</td><td>1193</td><td>5.0</td><td>5.0290117263793945</td></tr><tr><td>1021</td><td>2380</td><td>1.0</td><td>2.290351390838623</td></tr><tr><td>1021</td><td>2424</td><td>4.0</td><td>4.04727029800415</td></tr><tr><td>1021</td><td>2762</td><td>5.0</td><td>5.102728366851807</td></tr><tr><td>1021</td><td>2963</td><td>3.0</td><td>1.8556783199310303</td></tr><tr><td>1021</td><td>3113</td><td>4.0</td><td>3.3337180614471436</td></tr><tr><td>1021</td><td>3175</td><td>4.0</td><td>3.1299495697021484</td></tr><tr><td>2737</td><td>290</td><td>5.0</td><td>4.903825759887695</td></tr></tbody></table></div>

# %%
from pyspark.ml.evaluation import RegressionEvaluator

evaluator = RegressionEvaluator(
    metricName="rmse",
    labelCol="rating",
    predictionCol="prediction"
)

rmse = evaluator.evaluate(predictions)
print("RMSE =", rmse)
# Out:
# RMSE = 0.8261464717577105
