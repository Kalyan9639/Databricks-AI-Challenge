# %% [markdown]
# ### For today's task, I will be selecting the movie lens dataset which contains `100k ratings`.
#
# You can download the dataset from [here](https://grouplens.org/datasets/movielens/?utm_source=chatgpt.com)

# %%
df = spark.read.table("dai.phase2.ratings")
display(df.head(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>userId</th><th>movieId</th><th>rating</th><th>timestamp</th></tr></thead><tbody><tr><td>1</td><td>1</td><td>4.0</td><td>964982703</td></tr><tr><td>1</td><td>3</td><td>4.0</td><td>964981247</td></tr><tr><td>1</td><td>6</td><td>4.0</td><td>964982224</td></tr><tr><td>1</td><td>47</td><td>5.0</td><td>964983815</td></tr><tr><td>1</td><td>50</td><td>5.0</td><td>964982931</td></tr><tr><td>1</td><td>70</td><td>3.0</td><td>964982400</td></tr><tr><td>1</td><td>101</td><td>5.0</td><td>964980868</td></tr><tr><td>1</td><td>110</td><td>4.0</td><td>964982176</td></tr><tr><td>1</td><td>151</td><td>5.0</td><td>964984041</td></tr><tr><td>1</td><td>157</td><td>5.0</td><td>964984100</td></tr></tbody></table></div>

# %%
df.printSchema()
print(f"Shape: ({df.count()},{len(df.columns)})")
# Out:
# root
#  |-- userId: long (nullable = true)
#  |-- movieId: long (nullable = true)
#  |-- rating: double (nullable = true)
#  |-- timestamp: long (nullable = true)
#
# Shape: (100836,4)

# %%
ratings = df.drop("timestamp")
display(ratings.head(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>userId</th><th>movieId</th><th>rating</th></tr></thead><tbody><tr><td>1</td><td>1</td><td>4.0</td></tr><tr><td>1</td><td>3</td><td>4.0</td></tr><tr><td>1</td><td>6</td><td>4.0</td></tr><tr><td>1</td><td>47</td><td>5.0</td></tr><tr><td>1</td><td>50</td><td>5.0</td></tr><tr><td>1</td><td>70</td><td>3.0</td></tr><tr><td>1</td><td>101</td><td>5.0</td></tr><tr><td>1</td><td>110</td><td>4.0</td></tr><tr><td>1</td><td>151</td><td>5.0</td></tr><tr><td>1</td><td>157</td><td>5.0</td></tr></tbody></table></div>

# %%
display(ratings.select("rating").distinct())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>rating</th></tr></thead><tbody><tr><td>4.0</td></tr><tr><td>5.0</td></tr><tr><td>3.0</td></tr><tr><td>2.0</td></tr><tr><td>1.0</td></tr><tr><td>4.5</td></tr><tr><td>3.5</td></tr><tr><td>2.5</td></tr><tr><td>0.5</td></tr><tr><td>1.5</td></tr></tbody></table></div>

# %% [markdown]
# ### Training the ALS(Alternating Least Square) Model:
#
# > #### Steps to train ALS Model:
# > 1. Split the data and train and test sets
# > 2. Create ALS Model
# > 3. Train the Model
# > 4. Make Predictions
# > 5. Evaluate
#
# ---

# %%
# Creating the train and test data set
train, test = ratings.randomSplit([0.8, 0.2], seed=42)

# %%
train.count(),test.count()
# Out:
# (80481, 20355)

# %%
from pyspark.ml.recommendation import ALS

als = ALS(
    userCol="userId",
    itemCol="movieId",
    ratingCol="rating",
    rank=32,              # number of latent factors
    maxIter=10,           # number of iterations
    regParam=0.2,         # regularization
    implicitPrefs=False,  # because these are real ratings
    coldStartStrategy="drop"  # If a user appears in test not in train, this will drop those types of rows to prevent predicitng NaN
)

# %%
# Training the model
model = als.fit(train)

# %%
predictions = model.transform(test)
display(predictions.head(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>userId</th><th>movieId</th><th>rating</th><th>prediction</th></tr></thead><tbody><tr><td>1</td><td>151</td><td>5.0</td><td>4.075538635253906</td></tr><tr><td>1</td><td>216</td><td>5.0</td><td>3.757520914077759</td></tr><tr><td>1</td><td>231</td><td>5.0</td><td>3.387457847595215</td></tr><tr><td>1</td><td>362</td><td>5.0</td><td>3.996443510055542</td></tr><tr><td>1</td><td>423</td><td>3.0</td><td>3.7773244380950928</td></tr><tr><td>1</td><td>441</td><td>4.0</td><td>4.480555534362793</td></tr><tr><td>1</td><td>457</td><td>5.0</td><td>4.537994384765625</td></tr><tr><td>1</td><td>500</td><td>3.0</td><td>3.9462838172912598</td></tr><tr><td>1</td><td>552</td><td>4.0</td><td>3.6999552249908447</td></tr><tr><td>1</td><td>593</td><td>4.0</td><td>4.726114273071289</td></tr></tbody></table></div>

# %%
from pyspark.ml.evaluation import RegressionEvaluator

evaluator = RegressionEvaluator(
    metricName="rmse",
    labelCol="rating",
    predictionCol="prediction"
)

rmse = evaluator.evaluate(predictions)
print("RMSE =", rmse)
# Out:
# RMSE = 0.8830109920691748

# %% [markdown]
# ---
#
# I can't use the `recommendForUserSubset` method from the model. but its throwing me the error below:
#
# > [UC_COMMAND_NOT_SUPPORTED.WITHOUT_RECOMMENDATION] The command(s): Spark higher-order functions are not supported in Unity Catalog.  SQLSTATE: 0AKUC
#
# So, i will generate `Top-5 recommendations` without using `recommendForUserSubset`
#
# ---

# %%
users = ratings.select("userId").distinct()
movies = ratings.select("movieId").distinct()

# %%
user_movie = users.crossJoin(movies)

# %%
display(user_movie.head(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>userId</th><th>movieId</th></tr></thead><tbody><tr><td>28</td><td>151</td></tr><tr><td>29</td><td>480</td></tr><tr><td>30</td><td>1025</td></tr><tr><td>33</td><td>1219</td></tr><tr><td>93</td><td>1226</td></tr><tr><td>151</td><td>1552</td></tr><tr><td>171</td><td>1920</td></tr><tr><td>200</td><td>2054</td></tr><tr><td>208</td><td>2141</td></tr><tr><td>221</td><td>2273</td></tr></tbody></table></div>

# %%
predictions = model.transform(user_movie)

# %%
rated_movies = ratings.select("userId", "movieId")

unrated_predictions = predictions.join(
    rated_movies,
    ["userId", "movieId"],
    "left_anti"
)

# %%
from pyspark.sql.window import Window
from pyspark.sql.functions import row_number, col

window = Window.partitionBy("userId").orderBy(col("prediction").desc())

top5 = unrated_predictions \
    .withColumn("rank", row_number().over(window)) \
    .filter(col("rank") <= 5)

display(top5.head(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>userId</th><th>movieId</th><th>prediction</th><th>rank</th></tr></thead><tbody><tr><td>1</td><td>170355</td><td>5.989782333374023</td><td>1</td></tr><tr><td>1</td><td>5490</td><td>5.931138515472412</td><td>2</td></tr><tr><td>1</td><td>132333</td><td>5.931138515472412</td><td>3</td></tr><tr><td>1</td><td>5915</td><td>5.931138515472412</td><td>4</td></tr><tr><td>1</td><td>33649</td><td>5.776803970336914</td><td>5</td></tr><tr><td>2</td><td>170355</td><td>4.9758710861206055</td><td>1</td></tr><tr><td>2</td><td>5490</td><td>4.864869594573975</td><td>2</td></tr><tr><td>2</td><td>132333</td><td>4.864869594573975</td><td>3</td></tr><tr><td>2</td><td>5915</td><td>4.864869594573975</td><td>4</td></tr><tr><td>2</td><td>33649</td><td>4.816833019256592</td><td>5</td></tr></tbody></table></div>

# %%
top5.write.format("delta").mode('overwrite').save("/Volumes/dai/phase2/gold/top5_recommendations")
