# %% [markdown]
# #### In the previous session, we just logged the model as the artifact. But the correct way in the production is to log it to the `Model Registry`. Below is how you do that

# %%
import mlflow

mlflow.register_model(
    "runs:/911890e2080e4bec92daab111b23adc0/random_forest_model",
    "dai.phase2.rf_model_for_ecommerce"
    
)
# Out:
# Successfully registered model 'dai.phase2.rf_model_for_ecommerce'.
# Created version '1' of model 'dai.phase2.rf_model_for_ecommerce'.
# <ModelVersion: aliases=[], creation_timestamp=1772035093103, current_stage=None, description='', last_updated_timestamp=1772035099229, name='dai.phase2.rf_model_for_ecommerce', run_id='911890e2080e4bec92daab111b23adc0', run_link=None, source='dbfs:/databricks/mlflow-tracking/2289157703991855/911890e2080e4bec92daab111b23adc0/artifacts/random_forest_model', status='READY', status_message='', tags={}, user_id='kalyanmistcse@gmail.com', version='1'>
